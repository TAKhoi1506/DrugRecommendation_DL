# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data Điều trị
DieuTri_df = pd.read_csv(r'D:\OU\KhoaLuanTotNghiep\DrugRecommandation\preprocessData_DieuTri\DieuTri_processed.csv')
print("Số dòng và số cột của DataFrame: ", DieuTri_df.shape)
print("Các cột trong DataFram Điều trị: ", DieuTri_df.columns)
DieuTri_df.head()
# Out:
# Số dòng và số cột của DataFrame:  (1008, 12)
# Các cột trong DataFram Điều trị:  Index(['Tên thuốc', 'link', 'Chỉ định', 'Thành phần', 'Liều dùng', 'Cách dùng',
#        'Tác dụng phụ', 'Chống chỉ định', 'Thận trọng', 'Cảnh báo',
#        'Tương tác thuốc', 'Mang thai và cho con bú'],
#       dtype='object')
#                                            Tên thuốc  \
# 0                Azelastine: thuốc điều trị viêm mũi
# 1  Axit acetohydroxamic: thuốc điều trị nhiễm trù...
# 2  Axalimogene Filolisbac: thuốc điều trị ung thư...
# 3                   Avelumab: thuốc điều trị ung thư
# 4       Atovaquone Proguanil: thuốc điều trị sốt rét
#
#                                                 link Chỉ định Thành phần  \
# 0  https://www.dieutri.vn/a/azelastine-thuoc-dieu...      NaN        NaN
# 1  https://www.dieutri.vn/a/axit-acetohydroxamic-...      NaN        NaN
# 2  https://www.dieutri.vn/a/axalimogene-filolisba...      NaN        NaN
# ...

# %%
# Data Long Châu
LongChau_df = pd.read_csv(r'D:\OU\KhoaLuanTotNghiep\DrugRecommandation\preprocessData_LongChau\Longchau_data_processed.csv')
print("Số dòng và số cột của DataFrame: ", LongChau_df.shape)
print("Các cột trong DataFrame Long Châu: ", LongChau_df.columns)
LongChau_df.head()
# Out:
# Số dòng và số cột của DataFrame:  (5672, 12)
# Các cột trong DataFrame Long Châu:  Index(['url', 'ten_thuoc', 'gia', 'hinh_anh', 'thanh_phan', 'cong_dung',
#        'chong_chi_dinh', 'lieu_dung', 'luu_y', 'tac_dung_phu', 'bao_quan',
#        'mo_ta'],
#       dtype='object')
#                                                  url  \
# 0  https://nhathuoclongchau.com.vn/thuoc/5-fluoro...
# 1  https://nhathuoclongchau.com.vn/thuoc/actadol-...
# 2  https://nhathuoclongchau.com.vn/thuoc/allerpha...
# 3  https://nhathuoclongchau.com.vn/thuoc/ambroxol...
# 4  https://nhathuoclongchau.com.vn/thuoc/agiclovi...
#
#                                            ten_thuoc    gia  \
# 0  Thuốc 5-Fluorouracil 50mg Novartis điều trị gi...    NaN
# 1  Thuốc Actadol 500 Medipharco điều trị các chứn...  500.0
# 2  Thuốc Allerphast 180mg Mebiphar điều trị viêm ...    2.5
# 3  Siro Ambroxol Danapha điều trị viêm phế quản, ...   30.0
# 4  Thuốc mỡ bôi da Agiclovir 5% Agimexpharm điều ...   10.0
#
# ...

# %%
# Data An Khang
AnKhang_df = pd.read_csv(r'D:\OU\KhoaLuanTotNghiep\DrugRecommandation\crawlData_AnKhang\ankhang_medicines_data_full.csv')
print("Số dòng và số cột của DataFrame: ", AnKhang_df.shape)
print("Các cột trong DataFram An Khang: ", AnKhang_df.columns)
AnKhang_df.head()
# Out:
# Số dòng và số cột của DataFrame:  (2193, 20)
# Các cột trong DataFram An Khang:  Index(['ten_thuoc', 'gia', 'hinh_anh', 'cong_dung_tom_tat', 'thanh_phan_chinh',
#        'doi_tuong', 'thuong_hieu', 'noi_san_xuat', 'dang_bao_che', 'han_dung',
#        'thanh_phan_chi_tiet', 'cong_dung_chi_tiet', 'cach_dung',
#        'chong_chi_dinh', 'tac_dung_phu', 'luu_y', 'url', 'category',
#        'drug_type', 'error'],
#       dtype='object')
#                                            ten_thuoc       gia  \
# 0  Timi Roitin trị viêm dây thần kinh, thoái hóa ...  528.000₫
# 1  B Complex C bổ sung vitamin nhóm B và vitamin ...      800₫
# 2                                                NaN       NaN
# 3  Vitamin PP 50 Pharmedic ngăn ngừa thiếu nicoti...   12.000₫
# 4  Agi-Calci bổ sung canxi, trị loãng xương (20 v...  150.000₫
#
#                                             hinh_anh  \
# 0  https://cdn.tgdd.vn/Products/Images/10053/1304...
# ...

# %%
# Data Pharmacity
pharmacity_df_9 = pd.read_csv(r'D:\OU\KhoaLuanTotNghiep\DrugRecommandation\crawlData_Pharmacity\pharmacity_medicines_data_demo(9).csv')
print("Số dòng và số cột của DataFrame: ", pharmacity_df_9.shape)
print("Các cột trong DataFrame Pharmaciy: ", pharmacity_df_9.columns)
pharmacity_df_9.head()
# Out:
# Số dòng và số cột của DataFrame:  (3568, 24)
# Các cột trong DataFrame Pharmaciy:  Index(['name', 'price', 'images', 'nha_san_xuat', 'noi_san_xuat',
#        'thuoc_can_ke_don', 'hoat_chat', 'chi_dinh_tom_tat', 'dang_bao_che',
#        'quy_cach', 'luu_y', 'mo_ta', 'thanh_phan', 'chi_dinh_chi_tiet',
#        'huong_dan_su_dung', 'cach_su_dung', 'than_trong', 'thong_tin_san_xuat',
#        'url', 'category', 'drug_type', 'category_link', 'category_name',
#        'error'],
#       dtype='object')
#                                                 name         price  \
# 0  Viên nén Postinor 1 (Hộp 1 viên) - Ngừa thai k...  40.000 ₫/Hộp
# 1  Cerciorat Leon Farma (Hộp 1 vỉ x 1 viên) – Trá...  35.990 ₫/Hộp
# 2  Viên nén BOCINOR 1.5MG thuốc tránh thai khẩn c...   9.500 ₫/Hộp
# 3                            Avalo day (Hộp 28 viên)  25.000 ₫/Hộp
# 4                    Newlevo 0.03mg (1 vỉ x 28 viên)   8.000 ₫/Hộp
#
#                                               images       nha_san_xuat  \
# ...

# %%
# Kết hợp tất cả DataFrame lại với nhau
combined_df = pd.concat([DieuTri_df, LongChau_df, AnKhang_df, pharmacity_df_9], ignore_index=True)
print("Số dòng và số cột của DataFrame kết hợp: ", combined_df.shape)
combined_df.head()
# Out:
# Số dòng và số cột của DataFrame kết hợp:  (12441, 52)
#                                            Tên thuốc  \
# 0                Azelastine: thuốc điều trị viêm mũi
# 1  Axit acetohydroxamic: thuốc điều trị nhiễm trù...
# 2  Axalimogene Filolisbac: thuốc điều trị ung thư...
# 3                   Avelumab: thuốc điều trị ung thư
# 4       Atovaquone Proguanil: thuốc điều trị sốt rét
#
#                                                 link Chỉ định Thành phần  \
# 0  https://www.dieutri.vn/a/azelastine-thuoc-dieu...      NaN        NaN
# 1  https://www.dieutri.vn/a/axit-acetohydroxamic-...      NaN        NaN
# 2  https://www.dieutri.vn/a/axalimogene-filolisba...      NaN        NaN
# 3  https://www.dieutri.vn/a/avelumab-thuoc-dieu-t...      NaN        NaN
# 4  https://www.dieutri.vn/a/atovaquone-proguanil-...      NaN        NaN
#
#                                            Liều dùng Cách dùng  \
# 0  Thuốc xịt mũi 0,1% (137mcg / lần xịt). 0,15% (...       NaN
# ...
